# %% [markdown]
# <a href="https://colab.research.google.com/github/franciscoromillo/Practicing_python/blob/main/Ejercicios_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importemos la librería de Pandas:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Importemos nuestro dataset de la siguiente url: https://raw.githubusercontent.com/LearnDataSci/articles/master/Python%20Pandas%20Tutorial%20A%20Complete%20Introduction%20for%20Beginners/IMDB-Movie-Data.csv

# %%
df = pd.read_csv('https://raw.githubusercontent.com/LearnDataSci/articles/master/Python%20Pandas%20Tutorial%20A%20Complete%20Introduction%20for%20Beginners/IMDB-Movie-Data.csv', index_col = 0)

# %% [markdown]
# Hagamos una primer vistazo a los datos: cómo son, forma, información básica

# %%
df.head()
# Out:
#                         Title                     Genre  \
# Rank
# 1     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                  Prometheus  Adventure,Mystery,Sci-Fi
# 3                       Split           Horror,Thriller
# 4                        Sing   Animation,Comedy,Family
# 5               Suicide Squad  Action,Adventure,Fantasy
#
#                                             Description              Director  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# 3     Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 4     In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 5     A secret government agency recruits some of th...            David Ayer
#
#                                                  Actors  Year  \
# Rank
# 1     Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014
# ...

# %%
df.tail(2)
# Out:
#              Title                  Genre  \
# Rank
# 999   Search Party       Adventure,Comedy
# 1000    Nine Lives  Comedy,Family,Fantasy
#
#                                             Description          Director  \
# Rank
# 999   A pair of friends embark on a mission to reuni...    Scot Armstrong
# 1000  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                  Actors  Year  \
# Rank
# 999   Adam Pally, T.J. Miller, Thomas Middleditch,Sh...  2014
# 1000  Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...  2016
#
#       Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# Rank
# 999                  93     5.6   4881                 NaN       22.0
# 1000                 87     5.3  12435               19.64       11.0

# %%
df.shape
# Out:
# (1000, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1 to 1000
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               1000 non-null   object
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 93.8+ KB

# %% [markdown]
# Tenemos datos duplicados?

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (1000, 11)

# %% [markdown]
# Limpiemos los nombres de las columnas:

# %%
df.columns = [col.lower().replace(' ','_') for col in df]
df.head()
# Out:
#                         title                     genre  \
# Rank
# 1     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                  Prometheus  Adventure,Mystery,Sci-Fi
# 3                       Split           Horror,Thriller
# 4                        Sing   Animation,Comedy,Family
# 5               Suicide Squad  Action,Adventure,Fantasy
#
#                                             description              director  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# 3     Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 4     In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 5     A secret government agency recruits some of th...            David Ayer
#
#                                                  actors  year  \
# Rank
# 1     Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014
# ...

# %%
df.rename(columns = {'runtime_(minutes)' : 'runtime_min',
                     'revenue_(millions)' : 'revenue_mm'}, inplace=True)
df.head()
# Out:
#                         title                     genre  \
# Rank
# 1     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                  Prometheus  Adventure,Mystery,Sci-Fi
# 3                       Split           Horror,Thriller
# 4                        Sing   Animation,Comedy,Family
# 5               Suicide Squad  Action,Adventure,Fantasy
#
#                                             description              director  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# 3     Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 4     In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 5     A secret government agency recruits some of th...            David Ayer
#
#                                                  actors  year  runtime_min  \
# Rank
# ...

# %%
df.set_index('title')
# Out:
#                                             genre  \
# title
# Guardians of the Galaxy   Action,Adventure,Sci-Fi
# Prometheus               Adventure,Mystery,Sci-Fi
# Split                             Horror,Thriller
# Sing                      Animation,Comedy,Family
# Suicide Squad            Action,Adventure,Fantasy
# ...                                           ...
# Secret in Their Eyes          Crime,Drama,Mystery
# Hostel: Part II                            Horror
# Step Up 2: The Streets        Drama,Music,Romance
# Search Party                     Adventure,Comedy
# Nine Lives                  Comedy,Family,Fantasy
#
#                                                                description  \
# title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# ...

# %%
df.head()
# Out:
#                         title                     genre  \
# Rank
# 1     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                  Prometheus  Adventure,Mystery,Sci-Fi
# 3                       Split           Horror,Thriller
# 4                        Sing   Animation,Comedy,Family
# 5               Suicide Squad  Action,Adventure,Fantasy
#
#                                             description              director  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# 3     Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 4     In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 5     A secret government agency recruits some of th...            David Ayer
#
#                                                  actors  year  runtime_min  \
# Rank
# ...

# %% [markdown]
# Tenemos datos nulos?

# %%
df.isnull().sum()
# Out:
# title            0
# genre            0
# description      0
# director         0
# actors           0
# year             0
# runtime_min      0
# rating           0
# votes            0
# revenue_mm     128
# metascore       64
# dtype: int64

# %%
df.dropna()
# Out:
#                          title                     genre  \
# Rank
# 1      Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                   Prometheus  Adventure,Mystery,Sci-Fi
# 3                        Split           Horror,Thriller
# 4                         Sing   Animation,Comedy,Family
# 5                Suicide Squad  Action,Adventure,Fantasy
# ...                        ...                       ...
# 994   Resident Evil: Afterlife   Action,Adventure,Horror
# 995                  Project X                    Comedy
# 997            Hostel: Part II                    Horror
# 998     Step Up 2: The Streets       Drama,Music,Romance
# 1000                Nine Lives     Comedy,Family,Fantasy
#
#                                             description              director  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
df.dropna(subset=['metascore'], inplace=True)

# %%
df.shape
# Out:
# (936, 11)

# %%
df.tail()
# Out:
#                        title                  genre  \
# Rank
# 996     Secret in Their Eyes    Crime,Drama,Mystery
# 997          Hostel: Part II                 Horror
# 998   Step Up 2: The Streets    Drama,Music,Romance
# 999             Search Party       Adventure,Comedy
# 1000              Nine Lives  Comedy,Family,Fantasy
#
#                                             description          director  \
# Rank
# 996   A tight-knit team of rising investigators, alo...         Billy Ray
# 997   Three American college students studying abroa...          Eli Roth
# 998   Romantic sparks occur between two dance studen...        Jon M. Chu
# 999   A pair of friends embark on a mission to reuni...    Scot Armstrong
# 1000  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                  actors  year  runtime_min  \
# Rank
# 996   Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015          111
# ...

# %%
df.reset_index(inplace=True)

# %%
df.tail()
# Out:
#      Rank                   title                  genre  \
# 931   996    Secret in Their Eyes    Crime,Drama,Mystery
# 932   997         Hostel: Part II                 Horror
# 933   998  Step Up 2: The Streets    Drama,Music,Romance
# 934   999            Search Party       Adventure,Comedy
# 935  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            description          director  \
# 931  A tight-knit team of rising investigators, alo...         Billy Ray
# 932  Three American college students studying abroa...          Eli Roth
# 933  Romantic sparks occur between two dance studen...        Jon M. Chu
# 934  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 935  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 actors  year  runtime_min  \
# 931  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015          111
# ...

# %%
df.isnull().sum()
# Out:
# Rank            0
# title           0
# genre           0
# description     0
# director        0
# actors          0
# year            0
# runtime_min     0
# rating          0
# votes           0
# revenue_mm     98
# metascore       0
# dtype: int64

# %%
mean_revenue = df['revenue_mm'].mean()
print(mean_revenue)
# Out:
# 84.56455847255368

# %%
df.fillna(df['revenue_mm'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Rank           0
# title          0
# genre          0
# description    0
# director       0
# actors         0
# year           0
# runtime_min    0
# rating         0
# votes          0
# revenue_mm     0
# metascore      0
# dtype: int64

# %%
df.head()
# Out:
#    Rank                    title                     genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          description              director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               actors  year  runtime_min  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014          121
# ...

# %% [markdown]
# Pasemos a analizar los datos:
# * Cuántos directores distintos encontramos en nuestro dataframe?

# %%
df.shape
# Out:
# (936, 12)

# %%
df['director'].nunique()
# Out:
# 607

# %%
df['director'].unique()
# Out:
# array(['James Gunn', 'Ridley Scott', 'M. Night Shyamalan',
#        'Christophe Lourdelet', 'David Ayer', 'Yimou Zhang',
#        'Damien Chazelle', 'Sean Foley', 'James Gray', 'Morten Tyldum',
#        'David Yates', 'Theodore Melfi', 'Gareth Edwards', 'Ron Clements',
#        'Nacho Vigalondo', 'Chris Renaud', 'Mel Gibson', 'Paul Greengrass',
#        'Garth Davis', 'Denis Villeneuve', 'Stephen Gaghan',
#        'Kenneth Lonergan', 'Ben Young', 'Walt Dohrn', 'Roland Emmerich',
#        'Jon Lucas', 'Justin Kurzel', 'John Hamburg', 'Tom Ford',
#        'Bryan Singer', 'Tim Miller', 'Paul W.S. Anderson',
#        'Anthony Russo', 'Christopher Nolan', 'Scott Derrickson',
#        'Antoine Fuqua', 'Greg Tiernan', 'Barry Jenkins',
#        'John Lee Hancock', 'Ricardo de Montreuil', 'Rob Marshall',
#        'John Madden', 'Justin Lin', 'Sean Penn', 'J.J. Abrams',
#        'Anna Foerster', 'Garry Marshall', 'Chad Stahelski',
#        'Martin Scorsese', 'Fede Alvarez', 'Thea Sharrock',
# ...

# %% [markdown]
# * Cuáles son los 5 directores/as con más películas?

# %%
df['director'].value_counts().head()
# Out:
# Ridley Scott          8
# M. Night Shyamalan    6
# Paul W.S. Anderson    6
# Michael Bay           6
# David Yates           6
# Name: director, dtype: int64

# %% [markdown]
# * Cuáles son los top 10 géneros más populares?

# %%
df['genre'].value_counts().head(10)
# Out:
# Action,Adventure,Sci-Fi       50
# Drama                         43
# Comedy,Drama,Romance          32
# Comedy                        30
# Drama,Romance                 28
# Animation,Adventure,Comedy    26
# Action,Adventure,Fantasy      26
# Comedy,Romance                25
# Comedy,Drama                  25
# Crime,Drama,Thriller          22
# Name: genre, dtype: int64

# %% [markdown]
# * Veamos si hay datos correlacionados:

# %%
df.corr()
# Out:
#                  Rank      year  runtime_min    rating     votes  revenue_mm  \
# Rank         1.000000 -0.257146    -0.269281 -0.244541 -0.311417   -0.257086
# year        -0.257146  1.000000    -0.148636 -0.201293 -0.405762   -0.121985
# runtime_min -0.269281 -0.148636     1.000000  0.387009  0.424760    0.265400
# rating      -0.244541 -0.201293     0.387009  1.000000  0.521734    0.192790
# votes       -0.311417 -0.405762     0.424760  0.521734  1.000000    0.610492
# revenue_mm  -0.257086 -0.121985     0.265400  0.192790  0.610492    1.000000
# metascore   -0.191869 -0.079305     0.211978  0.631897  0.325684    0.132829
#
#              metascore
# Rank         -0.191869
# year         -0.079305
# runtime_min   0.211978
# rating        0.631897
# votes         0.325684
# revenue_mm    0.132829
# metascore     1.000000

# %% [markdown]
# * Cuál es el año de la película más reciente? Y de la más antigua?

# %%
df['year'].max()
# Out:
# 2016

# %%
df['year'].min()
# Out:
# 2006

# %% [markdown]
# * Cuál es la nota media de toda la base de peliculas?

# %%
df.head()
# Out:
#    Rank                    title                     genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          description              director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               actors  year  runtime_min  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014          121
# ...

# %%
df['rating'].mean()
# Out:
# 6.729166666666667

# %%
df['rating'].median()
# Out:
# 6.8

# %%
df
# Out:
#      Rank                    title                     genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 931   996     Secret in Their Eyes       Crime,Drama,Mystery
# 932   997          Hostel: Part II                    Horror
# 933   998   Step Up 2: The Streets       Drama,Music,Romance
# 934   999             Search Party          Adventure,Comedy
# 935  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            description              director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.to_csv('drive\imdb_films.csv')

# %%
sub_df = df[['title', 'director', 'rating']]

# %%
sub_df.set_index('title', inplace=True)

# %%
sub_df.head()
# Out:
#                                      director  rating
# title
# Guardians of the Galaxy            James Gunn     8.1
# Prometheus                       Ridley Scott     7.0
# Split                      M. Night Shyamalan     7.3
# Sing                     Christophe Lourdelet     7.2
# Suicide Squad                      David Ayer     6.2

# %%
sub_df.iloc[0:3]
# Out:
#                                    director  rating
# title
# Guardians of the Galaxy          James Gunn     8.1
# Prometheus                     Ridley Scott     7.0
# Split                    M. Night Shyamalan     7.3

# %%
sub_df.loc['Guardians of the Galaxy':'Sing']
# Out:
#                                      director  rating
# title
# Guardians of the Galaxy            James Gunn     8.1
# Prometheus                       Ridley Scott     7.0
# Split                      M. Night Shyamalan     7.3
# Sing                     Christophe Lourdelet     7.2

# %%
runmin_120 = df[(df['runtime_min']>120)]

# %%
df1 = df[(df['director'] == 'James Gunn') | (df['director'] == 'Ridley Scott')]

# %%
df.head()
# Out:
#    Rank                    title                     genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          description              director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               actors  year  runtime_min  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014          121
# ...

# %%
df.pop('Rank')
df
# Out:
#                        title                     genre  \
# 0    Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1                 Prometheus  Adventure,Mystery,Sci-Fi
# 2                      Split           Horror,Thriller
# 3                       Sing   Animation,Comedy,Family
# 4              Suicide Squad  Action,Adventure,Fantasy
# ..                       ...                       ...
# 931     Secret in Their Eyes       Crime,Drama,Mystery
# 932          Hostel: Part II                    Horror
# 933   Step Up 2: The Streets       Drama,Music,Romance
# 934             Search Party          Adventure,Comedy
# 935               Nine Lives     Comedy,Family,Fantasy
#
#                                            description              director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# 1    Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
sub_df.head(20)
# Out:
#                                                      director  rating
# title
# Guardians of the Galaxy                            James Gunn     8.1
# Prometheus                                       Ridley Scott     7.0
# Split                                      M. Night Shyamalan     7.3
# Sing                                     Christophe Lourdelet     7.2
# Suicide Squad                                      David Ayer     6.2
# The Great Wall                                    Yimou Zhang     6.1
# La La Land                                    Damien Chazelle     8.3
# Mindhorn                                           Sean Foley     6.4
# The Lost City of Z                                 James Gray     7.1
# Passengers                                      Morten Tyldum     7.0
# Fantastic Beasts and Where to Find Them           David Yates     7.5
# Hidden Figures                                 Theodore Melfi     7.8
# ...

# %%
sub_df.drop(['Passengers', 'Hidden Figures'], inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
sub_df.head(20)
# Out:
#                                                      director  rating
# title
# Guardians of the Galaxy                            James Gunn     8.1
# Prometheus                                       Ridley Scott     7.0
# Split                                      M. Night Shyamalan     7.3
# Sing                                     Christophe Lourdelet     7.2
# Suicide Squad                                      David Ayer     6.2
# The Great Wall                                    Yimou Zhang     6.1
# La La Land                                    Damien Chazelle     8.3
# Mindhorn                                           Sean Foley     6.4
# The Lost City of Z                                 James Gray     7.1
# Fantastic Beasts and Where to Find Them           David Yates     7.5
# Rogue One                                      Gareth Edwards     7.9
# Moana                                            Ron Clements     7.7
# ...

# %%
sub_df.reset_index(inplace=True)
sub_df.drop([0,2])
# Out:
#      index                   title              director  rating
# 1        1              Prometheus          Ridley Scott     7.0
# 3        3                    Sing  Christophe Lourdelet     7.2
# 4        4           Suicide Squad            David Ayer     6.2
# 5        5          The Great Wall           Yimou Zhang     6.1
# 6        6              La La Land       Damien Chazelle     8.3
# ..     ...                     ...                   ...     ...
# 929    929    Secret in Their Eyes             Billy Ray     6.2
# 930    930         Hostel: Part II              Eli Roth     5.5
# 931    931  Step Up 2: The Streets            Jon M. Chu     6.2
# 932    932            Search Party        Scot Armstrong     5.6
# 933    933              Nine Lives      Barry Sonnenfeld     5.3
#
# [932 rows x 4 columns]

# %%
def new_old_film(x):
  if x==2016:
    return 'new'
  else:
    return 'old'

# %%
df['ind_new'] = df['year'].apply(new_old_film)

# %%
df.head()
# Out:
#                      title                     genre  \
# 0  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1               Prometheus  Adventure,Mystery,Sci-Fi
# 2                    Split           Horror,Thriller
# 3                     Sing   Animation,Comedy,Family
# 4            Suicide Squad  Action,Adventure,Fantasy
#
#                                          description              director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               actors  year  runtime_min  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014          121
# ...

# %%
df.groupby(['genre']).agg(np.mean)
# Out:
#                                    year  runtime_min    rating          votes  \
# genre
# Action                      2016.000000    90.000000  4.900000    6809.000000
# Action,Adventure            2011.000000   124.333333  6.400000  334459.000000
# Action,Adventure,Biography  2015.500000   131.500000  7.000000   48780.000000
# Action,Adventure,Comedy     2014.214286   109.642857  6.592857  193502.357143
# Action,Adventure,Crime      2012.333333   116.500000  6.433333  200322.833333
# ...                                 ...          ...       ...            ...
# Romance,Sci-Fi              2016.000000   118.000000  6.100000     512.000000
# Sci-Fi                      2016.000000   101.000000  4.000000     277.000000
# Sci-Fi,Thriller             2008.000000    91.000000  5.000000  170897.000000
# Thriller                    2015.714286    92.142857  5.771429   12097.142857
# Thriller,War                2016.000000   106.000000  6.000000    5926.000000
#
# ...

# %%
df[['genre', 'runtime_min']].groupby(['genre']).agg(np.mean).sort_values('runtime_min', ascending=False).head()
# Out:
#                          runtime_min
# genre
# Biography,Comedy,Crime         180.0
# Drama,Family,Music             165.0
# Drama,Western                  165.0
# Adventure,Drama,History        161.0
# Adventure,Fantasy              158.0

# %%
df[['rating', 'director', 'year', 'votes']].groupby(['director', 'year']).agg(np.max)
# Out:
#                           rating   votes
# director            year
# Aamir Khan          2007     8.5  102697
# Abdellatif Kechiche 2013     7.8  103150
# Adam Leon           2016     6.5    1031
# Adam McKay          2006     6.6  137502
#                     2008     6.9  223065
# ...                          ...     ...
# Zack Snyder         2009     7.6  410249
#                     2011     6.1  204874
#                     2013     7.1  577010
#                     2016     6.7  472307
# Zackary Adler       2015     5.1    1630
#
# [927 rows x 2 columns]
